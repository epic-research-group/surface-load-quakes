# %%
# Goal is to write a new CSV file with columns:
# id,latitude,longitude,time,magnitude
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from global_land_mask import globe

# %%
# Load datasets
earthquake_catalog = pd.read_csv('eq_200204_202102.csv')
earthquake_catalog["time"] = earthquake_catalog["time"].astype("datetime64")

# %%
earthquake_catalog_mini = earthquake_catalog.drop(columns=['depth', 'magType','nst','gap','dmin','net','horizontalError',
                                                     'updated','rms','place','type','depthError','magError','status',
                                                     'locationSource','magSource','magNst','id'])
earthquake_catalog_mini = earthquake_catalog_mini[['latitude', 'longitude', 'time', 'mag']]
earthquake_catalog_mini = earthquake_catalog_mini.rename(columns={"mag": "magnitude"})
earthquake_catalog_mini.to_csv (r'eq_200204_202102_mini.csv', index = True, header=True)

# %%
earthquake_catalog_mini
# Out:
#        latitude  longitude                    time  magnitude
# 0      -23.1842   171.7786 2021-02-17 22:49:38.110        6.1
# 1       30.8390    51.3651 2021-02-17 18:35:35.180        5.4
# 2      -17.4717   167.6675 2021-02-17 12:21:42.826        5.5
# 3       38.4057    22.0190 2021-02-17 03:36:07.058        5.5
# 4      -17.8133   167.6409 2021-02-16 01:32:00.512        5.9
# ...         ...        ...                     ...        ...
# 11922  -16.3820   173.2590 2002-04-20 15:59:57.860        6.0
# 11923   17.2330  -101.2500 2002-04-18 17:57:27.700        5.9
# 11924  -27.5350   -70.5860 2002-04-18 16:08:36.780        6.7
# 11925  -60.6570   -25.8430 2002-04-18 14:17:23.940        5.8
# 11926   16.9850  -100.8650 2002-04-18 05:02:46.190        6.8
#
# [11927 rows x 4 columns]
